# %% [markdown]
# <a href="https://colab.research.google.com/github/AlphaNerdFx/AI-Code-Filesystem-Management-Agent/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Styles of Functions

# %%
def simple():pass

# %%
def simple2():
  print('simple')

# %%
simple2()
# Out:
# simple

# %% [markdown]
# # Most useful

# %%
def my_worker(fruit):
  statement = f'My favourite meal is chicken and {fruit}'
  meals = {'dinner':statement}
  return meals

# %%
meal = my_worker('apple')

# %%
type(meal)
# Out:
# dict

# %%
meal.keys(), meal.values()
# Out:
# (dict_keys(['dinner']),
#  dict_values(['My favourite meal is chicken and apple']))

# %%
def human(food):
  consume = food['dinner']
  return consume

# %%
my_meal=human(meal)
print(f'I want my meal. It will be: {my_meal}')
# Out:
# I want my meal. It will be: My favourite meal is chicken and apple
